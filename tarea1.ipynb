# %% [markdown]
# ## FELIPE MANOLI

# %%
import random
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import csv

# %%
data2 = pd.read_csv('https://github.com/MinCiencia/Datos-COVID19/blob/master/output/producto1/Covid-19.csv?raw=true', sep=',')

# %%
data22= data2.drop(columns='Region')
data23= data22.drop(columns='Comuna')
data24= data23.drop(columns='Poblacion')
data25= data24.drop(columns='Codigo comuna')
#columnas innecesarias

# %%
data25=data25.dropna()
#Eliminos los na del df

# %%
regiones=data25.groupby("Codigo region", as_index=False).sum()
regiones
# Out:
#     Codigo region  2020-03-30  2020-04-01  2020-04-03  2020-04-06  2020-04-08  \
# 0               1         5.0         9.0        10.0        18.0        22.0
# 1               2        29.0        32.0        49.0        65.0        72.0
# 2               3         0.0         0.0         4.0         4.0         5.0
# 3               4        21.0        23.0        31.0        49.0        54.0
# 4               5        81.0       111.0       142.0       162.0       194.0
# 5               6         7.0        17.0        24.0        31.0        31.0
# 6               7        48.0        55.0        67.0        88.0       101.0
# 7               8        72.0       224.0       263.0       360.0       409.0
# 8               9       187.0       288.0       408.0       530.0       613.0
# 9              10       104.0       169.0       198.0       250.0       283.0
# 10             11         0.0         0.0         4.0         5.0         4.0
# ...

# %%
#plt.figure(figsize=(4,4))
#sns.lineplot(x="Codigo region",y=, data=regiones)

# %%
from seaborn import load_dataset

regiones=data25.groupby("Codigo region", as_index=False).sum()


region1 = regiones.iloc[2]


max(region1)
#Maximo de personas en cuarentena es de 76965 persona
# Out:
# 76965.3

# %%
#no pude graficar, intente de muchas maneras pero finalmente no se me dio, no me tomaba nunca las columnas para hacer los graficos.
